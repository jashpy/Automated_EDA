# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.to_csv("iris.csv")

# %%
filename=("iris.csv")

# %%
pip install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.720-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 3.5 MB/s eta 0:00:00
# Collecting emoji
#   Downloading emoji-2.5.1.tar.gz (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.3/356.3 kB 24.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fsspec>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from autoviz) (2022.11.0)
# Collecting hvplot~=0.7.3
#   Downloading hvplot-0.7.3-py2.py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 60.9 MB/s eta 0:00:00:00:01
# Collecting panel>=0.12.6
#   Downloading panel-1.1.1-py2.py3-none-any.whl (20.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 43.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from autoviz) (1.2.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from autoviz) (1.5.2)
# Requirement already satisfied: matplotlib>=3.3.3 in /opt/conda/lib/python3.10/site-packages (from autoviz) (3.6.2)
# Collecting holoviews~=1.14.9
#   Downloading holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 77.1 MB/s eta 0:00:00:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from autoviz) (1.23.5)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.10/site-packages (from autoviz) (8.7.0)
# Requirement already satisfied: xlrd in /opt/conda/lib/python3.10/site-packages (from autoviz) (2.0.1)
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 70.3 MB/s eta 0:00:00
# Collecting pandas-dq==1.28
#   Downloading pandas_dq-1.28-py3-none-any.whl (25 kB)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.10/site-packages (from autoviz) (0.13.5)
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 kB 49.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from autoviz) (4.4.0)
# Collecting bokeh~=2.4.2
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 47.1 MB/s eta 0:00:0000:0100:01
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.8/636.8 kB 59.8 MB/s eta 0:00:00
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting pyamg
#   Downloading pyamg-5.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 62.6 MB/s eta 0:00:00
# Collecting xgboost>=0.82
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 12.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: seaborn>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from autoviz) (0.12.1)
# Requirement already satisfied: Jinja2>=2.9 in /opt/conda/lib/python3.10/site-packages (from bokeh~=2.4.2->autoviz) (3.1.2)
# Requirement already satisfied: packaging>=16.8 in /opt/conda/lib/python3.10/site-packages (from bokeh~=2.4.2->autoviz) (22.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/conda/lib/python3.10/site-packages (from bokeh~=2.4.2->autoviz) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in /opt/conda/lib/python3.10/site-packages (from bokeh~=2.4.2->autoviz) (9.2.0)
# Requirement already satisfied: tornado>=5.1 in /opt/conda/lib/python3.10/site-packages (from bokeh~=2.4.2->autoviz) (6.1)
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.3.2-py2.py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 12.2 MB/s eta 0:00:00
# Collecting colorcet
#   Downloading colorcet-3.0.1-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.4 MB/s eta 0:00:00
# Collecting param<2.0,>=1.9.3
#   Downloading param-1.13.0-py2.py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.3->autoviz) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->autoviz) (2022.6)
# Collecting markdown-it-py<3
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 15.1 MB/s eta 0:00:00
# Collecting linkify-it-py
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/conda/lib/python3.10/site-packages (from panel>=0.12.6->autoviz) (2022.9.0)
# Requirement already satisfied: tqdm>=4.48.0 in /opt/conda/lib/python3.10/site-packages (from panel>=0.12.6->autoviz) (4.64.1)
# Collecting panel>=0.12.6
#   Downloading panel-1.1.0-py2.py3-none-any.whl (20.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 53.4 MB/s eta 0:00:0000:0100:01
#   Downloading panel-1.0.4-py2.py3-none-any.whl (20.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 31.3 MB/s eta 0:00:0000:0100:01
#   Downloading panel-1.0.3-py2.py3-none-any.whl (19.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 61.7 MB/s eta 0:00:0000:0100:01
#   Downloading panel-1.0.2-py2.py3-none-any.whl (19.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 53.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools>=42 in /opt/conda/lib/python3.10/site-packages (from panel>=0.12.6->autoviz) (65.5.1)
#   Downloading panel-1.0.1-py2.py3-none-any.whl (19.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 48.1 MB/s eta 0:00:0000:0100:01
#   Downloading panel-1.0.0-py2.py3-none-any.whl (19.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 54.2 MB/s eta 0:00:0000:0100:01
#   Downloading panel-0.14.4-py2.py3-none-any.whl (20.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 46.6 MB/s eta 0:00:0000:0100:01
# Collecting markdown
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from panel>=0.12.6->autoviz) (5.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from panel>=0.12.6->autoviz) (2.28.1)
# Collecting pyct>=0.4.4
#   Downloading pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->autoviz) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->autoviz) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->autoviz) (1.9.3)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (3.0.36)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (5.7.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (5.1.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (4.8.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (0.18.2)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (2.13.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.10/site-packages (from jupyter->autoviz) (6.19.2)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (from jupyter->autoviz) (8.0.3)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.10/site-packages (from jupyter->autoviz) (6.5.2)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.10/site-packages (from jupyter->autoviz) (7.2.6)
# Collecting qtconsole
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 18.1 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting regex>=2021.8.3
#   Downloading regex-2023.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.4/770.4 kB 57.5 MB/s eta 0:00:00
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk->autoviz) (8.1.3)
# Requirement already satisfied: patsy>=0.5.2 in /opt/conda/lib/python3.10/site-packages (from statsmodels->autoviz) (0.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython->autoviz) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh~=2.4.2->autoviz) (2.1.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython->autoviz) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython->autoviz) (0.2.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->panel>=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (1.6.4)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (5.9.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->autoviz) (24.0.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter->autoviz) (4.0.4)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter->autoviz) (3.0.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from jupyter-console->jupyter->autoviz) (5.1.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (2.0.4)
# Requirement already satisfied: nbformat>=5.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (5.7.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (0.7.2)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->autoviz) (4.11.1)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (0.15.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (0.17.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (21.3.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (0.4.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->panel>=0.12.6->autoviz) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->panel>=0.12.6->autoviz) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->panel>=0.12.6->autoviz) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->panel>=0.12.6->autoviz) (3.4)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->autoviz) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->autoviz) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->autoviz) (1.2.0)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->autoviz) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->autoviz) (2.6.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.23.3)
# Requirement already satisfied: notebook-shim>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter->autoviz) (0.2.2)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz) (2.3.2.post1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->autoviz) (0.19.2)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.4.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->autoviz) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz) (2.21)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.5.1-py2.py3-none-any.whl size=351211 sha256=ff4b2590027fce029b7ed708cbc3aea510dba4e276e33a106d196253e3dbedb3
#   Stored in directory: /home/jovyan/.cache/pip/wheels/eb/20/3c/5fd1add8fe5078a1fccc478726dfe8558eca5bfa5ba5b28405
# Successfully built emoji
# Installing collected packages: regex, qtpy, param, markdown, emoji, xgboost, pyviz-comms, pyct, pyamg, nltk, bokeh, wordcloud, textblob, panel, pandas-dq, colorcet, holoviews, qtconsole, jupyter-console, hvplot, jupyter, autoviz
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.0.3
#     Uninstalling bokeh-3.0.3:
#       Successfully uninstalled bokeh-3.0.3
# Successfully installed autoviz-0.1.720 bokeh-2.4.3 colorcet-3.0.1 emoji-2.5.1 holoviews-1.14.9 hvplot-0.7.3 jupyter-1.0.0 jupyter-console-6.6.3 markdown-3.4.3 nltk-3.8.1 pandas-dq-1.28 panel-0.14.4 param-1.13.0 pyamg-5.0.0 pyct-0.5.0 pyviz-comms-2.3.2 qtconsole-5.4.3 qtpy-2.3.1 regex-2023.6.3 textblob-0.17.1 wordcloud-1.9.2 xgboost-1.7.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
from autoviz.AutoViz_Class import AutoViz_Class
av=AutoViz_Class()
dft=av.AutoViz(
    filename
)
# Out:
# Shape of your Data Set loaded: (150, 5)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     5 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Unnamed: 0']
# To fix data quality issues automatically, import FixDQ from autoviz...
# <style type="text/css">
# #T_33515_row0_col0, #T_33515_row0_col2, #T_33515_row0_col5, #T_33515_row1_col0, #T_33515_row1_col2, #T_33515_row1_col5, #T_33515_row2_col0, #T_33515_row2_col2, #T_33515_row2_col5, #T_33515_row3_col0, #T_33515_row3_col2, #T_33515_row3_col5, #T_33515_row4_col0, #T_33515_row4_col2, #T_33515_row4_col5 {
#   font-family: Segoe UI;
# }
# #T_33515_row0_col1, #T_33515_row0_col3, #T_33515_row1_col1, #T_33515_row2_col1, #T_33515_row3_col1, #T_33515_row4_col1, #T_33515_row4_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_33515_row0_col4, #T_33515_row1_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_33515_row1_col4 {
#   background-color: #ffefe8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_33515_row2_col3 {
#   background-color: #fb7555;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_33515_row2_col4 {
#   background-color: #fff3ed;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_33515_row3_col3 {
#   background-color: #fcc1a8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_33515_row3_col4 {
#   background-color: #fff0e9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_33515_row4_col3 {
#   background-color: #fff2eb;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_33515">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33515_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_33515_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_33515_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_33515_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_33515_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_33515_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33515_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_33515_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_33515_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_33515_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_33515_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_33515_row0_col4" class="data row0 col4" >149.000000</td>
#       <td id="T_33515_row0_col5" class="data row0 col5" >Possible ID colum: drop before modeling process.</td>
#     </tr>
#     <tr>
#       <th id="T_33515_level0_row1" class="row_heading level0 row1" >sepal length (cm)</th>
#       <td id="T_33515_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_33515_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_33515_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_33515_row1_col3" class="data row1 col3" >4.300000</td>
#       <td id="T_33515_row1_col4" class="data row1 col4" >7.900000</td>
#       <td id="T_33515_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_33515_level0_row2" class="row_heading level0 row2" >sepal width (cm)</th>
#       <td id="T_33515_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_33515_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_33515_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_33515_row2_col3" class="data row2 col3" >2.000000</td>
#       <td id="T_33515_row2_col4" class="data row2 col4" >4.400000</td>
#       <td id="T_33515_row2_col5" class="data row2 col5" >has 4 outliers greater than upper bound (4.05) or lower than lower bound(2.05). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_33515_level0_row3" class="row_heading level0 row3" >petal length (cm)</th>
#       <td id="T_33515_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_33515_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_33515_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_33515_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_33515_row3_col4" class="data row3 col4" >6.900000</td>
#       <td id="T_33515_row3_col5" class="data row3 col5" >has a high correlation with ['Unnamed: 0', 'sepal length (cm)']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_33515_level0_row4" class="row_heading level0 row4" >petal width (cm)</th>
#       <td id="T_33515_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_33515_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_33515_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_33515_row4_col3" class="data row4 col3" >0.100000</td>
#       <td id="T_33515_row4_col4" class="data row4 col4" >2.500000</td>
#       <td id="T_33515_row4_col5" class="data row4 col5" >has a high correlation with ['Unnamed: 0', 'sepal length (cm)', 'petal length (cm)']. Consider dropping one of them.</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 10
# All Plots done
# Time to run AutoViz = 5 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
